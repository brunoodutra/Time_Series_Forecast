# %%
import os, sys
import pandas as pd 
processing_source_path = os.path.abspath('Processing/')
if(processing_source_path not in sys.path):
    sys.path.append(processing_source_path)
from DataLoaderPipeline import scrapingHistoricalData

# %%
SHD=scrapingHistoricalData()

# Lista de criptomoedas
interval = '4h'#

#df=SHD.get_crypto_historical_data(cryptos, interval, '2015-01-01')
import datetime
init_date = '2013-01-01'
#init_date = '2020-01-01'
init_date_object = datetime.datetime.strptime(init_date, '%Y-%m-%d').date()

date_now = datetime.date.today()

diff_years = date_now.year - init_date_object.year
year_window = 1


cryptos_list = ['BTC','ETH','ENA','RAY','SOL','DOT','FET']
#cryptos_list = ['BTC','ETH']

if year_window > diff_years:
    raise ValueError("O intervalo de anos (year_window) é maior do que o período disponível nos dados.")
end_time=date_now.strftime('%Y-%m-%d')
#

# %%
#cryptos=cryptos_list[0]
for cryptos in cryptos_list:
    aux=[]
    for stride_year in range(0, diff_years-year_window+1,year_window):
        init_time=f'{init_date_object.year+stride_year}-01-01'

        look_year=init_date_object.year+stride_year+year_window
        if date_now.year == look_year:
            end_time=date_now.strftime('%Y-%m-%d')
        else:
            end_time=f'{look_year}-01-01'
        print(f'{cryptos} Dataset Period:{init_time} : {end_time}') 

        # Caminho do arquivo
        file_folder = f'Data_history/{cryptos}_{interval}_{init_time}_{end_time}.csv'

        cryptos_df = SHD.get_crypto_historical_data([cryptos], interval, init_time, end_time)
        aux+=[cryptos_df]
    crypto_all_time_df = pd.concat(aux, ignore_index=True)

    init_data_df=crypto_all_time_df['Date'][0].strftime('%Y-%m-%d')
    file_folder = f'Data_history/{cryptos}_{interval}_{init_data_df}_{end_time}.csv'
    crypto_all_time_df.to_csv(file_folder)
# Out:
# BTC Dataset Period:2013-01-01 : 2014-01-01
# Não há dados disponíveis.
# BTC Dataset Period:2014-01-01 : 2015-01-01
# Não há dados disponíveis.
# BTC Dataset Period:2015-01-01 : 2016-01-01
# Não há dados disponíveis.
# BTC Dataset Period:2016-01-01 : 2017-01-01
# Não há dados disponíveis.
# BTC Dataset Period:2017-01-01 : 2018-01-01
# BTC Dataset Period:2018-01-01 : 2019-01-01
# BTC Dataset Period:2019-01-01 : 2020-01-01
# BTC Dataset Period:2020-01-01 : 2021-01-01
# BTC Dataset Period:2021-01-01 : 2022-01-01
# BTC Dataset Period:2022-01-01 : 2023-01-01
# BTC Dataset Period:2023-01-01 : 2024-01-01
# BTC Dataset Period:2024-01-01 : 2025-02-27
# ETH Dataset Period:2013-01-01 : 2014-01-01
# Não há dados disponíveis.
# ETH Dataset Period:2014-01-01 : 2015-01-01
# Não há dados disponíveis.
# ETH Dataset Period:2015-01-01 : 2016-01-01
# Não há dados disponíveis.
# ETH Dataset Period:2016-01-01 : 2017-01-01
# Não há dados disponíveis.
# ETH Dataset Period:2017-01-01 : 2018-01-01
# ETH Dataset Period:2018-01-01 : 2019-01-01
# ETH Dataset Period:2019-01-01 : 2020-01-01
# ETH Dataset Period:2020-01-01 : 2021-01-01
# ETH Dataset Period:2021-01-01 : 2022-01-01
# ETH Dataset Period:2022-01-01 : 2023-01-01
# ETH Dataset Period:2023-01-01 : 2024-01-01
# ETH Dataset Period:2024-01-01 : 2025-02-27
# ENA Dataset Period:2013-01-01 : 2014-01-01
# Não há dados disponíveis.
# ENA Dataset Period:2014-01-01 : 2015-01-01
# Não há dados disponíveis.
# ENA Dataset Period:2015-01-01 : 2016-01-01
# Não há dados disponíveis.
# ENA Dataset Period:2016-01-01 : 2017-01-01
# Não há dados disponíveis.
# ENA Dataset Period:2017-01-01 : 2018-01-01
# Não há dados disponíveis.
# ENA Dataset Period:2018-01-01 : 2019-01-01
# Não há dados disponíveis.
# ENA Dataset Period:2019-01-01 : 2020-01-01
# Não há dados disponíveis.
# ENA Dataset Period:2020-01-01 : 2021-01-01
# Não há dados disponíveis.
# ENA Dataset Period:2021-01-01 : 2022-01-01
# Não há dados disponíveis.
# ENA Dataset Period:2022-01-01 : 2023-01-01
# Não há dados disponíveis.
# ENA Dataset Period:2023-01-01 : 2024-01-01
# Não há dados disponíveis.
# ENA Dataset Period:2024-01-01 : 2025-02-27
# RAY Dataset Period:2013-01-01 : 2014-01-01
# Não há dados disponíveis.
# RAY Dataset Period:2014-01-01 : 2015-01-01
# Não há dados disponíveis.
# RAY Dataset Period:2015-01-01 : 2016-01-01
# Não há dados disponíveis.
# RAY Dataset Period:2016-01-01 : 2017-01-01
# Não há dados disponíveis.
# RAY Dataset Period:2017-01-01 : 2018-01-01
# Não há dados disponíveis.
# RAY Dataset Period:2018-01-01 : 2019-01-01
# Não há dados disponíveis.
# RAY Dataset Period:2019-01-01 : 2020-01-01
# Não há dados disponíveis.
# RAY Dataset Period:2020-01-01 : 2021-01-01
# Não há dados disponíveis.
# RAY Dataset Period:2021-01-01 : 2022-01-01
# RAY Dataset Period:2022-01-01 : 2023-01-01
# RAY Dataset Period:2023-01-01 : 2024-01-01
# RAY Dataset Period:2024-01-01 : 2025-02-27
# SOL Dataset Period:2013-01-01 : 2014-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2014-01-01 : 2015-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2015-01-01 : 2016-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2016-01-01 : 2017-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2017-01-01 : 2018-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2018-01-01 : 2019-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2019-01-01 : 2020-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2020-01-01 : 2021-01-01
# SOL Dataset Period:2021-01-01 : 2022-01-01
# SOL Dataset Period:2022-01-01 : 2023-01-01
# SOL Dataset Period:2023-01-01 : 2024-01-01
# SOL Dataset Period:2024-01-01 : 2025-02-27
# DOT Dataset Period:2013-01-01 : 2014-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2014-01-01 : 2015-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2015-01-01 : 2016-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2016-01-01 : 2017-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2017-01-01 : 2018-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2018-01-01 : 2019-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2019-01-01 : 2020-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2020-01-01 : 2021-01-01
# DOT Dataset Period:2021-01-01 : 2022-01-01
# DOT Dataset Period:2022-01-01 : 2023-01-01
# DOT Dataset Period:2023-01-01 : 2024-01-01
# DOT Dataset Period:2024-01-01 : 2025-02-27
# FET Dataset Period:2013-01-01 : 2014-01-01
# Não há dados disponíveis.
# FET Dataset Period:2014-01-01 : 2015-01-01
# Não há dados disponíveis.
# FET Dataset Period:2015-01-01 : 2016-01-01
# Não há dados disponíveis.
# FET Dataset Period:2016-01-01 : 2017-01-01
# Não há dados disponíveis.
# FET Dataset Period:2017-01-01 : 2018-01-01
# Não há dados disponíveis.
# FET Dataset Period:2018-01-01 : 2019-01-01
# Não há dados disponíveis.
# FET Dataset Period:2019-01-01 : 2020-01-01
# FET Dataset Period:2020-01-01 : 2021-01-01
# FET Dataset Period:2021-01-01 : 2022-01-01
# FET Dataset Period:2022-01-01 : 2023-01-01
# FET Dataset Period:2023-01-01 : 2024-01-01
# FET Dataset Period:2024-01-01 : 2025-02-27

# %%
from glob import glob
[crypto_data for crypto_data in glob("Data_history/*")  if cryptos in crypto_data][0]
cryptos_df=pd.read_csv(file_folder, index_col=0)
