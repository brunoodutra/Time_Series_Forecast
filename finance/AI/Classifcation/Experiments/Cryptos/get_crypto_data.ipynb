# %%
import os, sys
import pandas as pd 
processing_source_path = os.path.abspath('./../../../Processing/')
if(processing_source_path not in sys.path):
    sys.path.append(processing_source_path)
from DataLoaderPipeline import scrapingHistoricalData
# Out:
# WARNING:tensorflow:From d:\Projetos_python\Time_Series_Forecast\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
SHD=scrapingHistoricalData()

# Lista de criptomoedas
interval = '4h'#

#df=SHD.get_crypto_historical_data(cryptos, interval, '2015-01-01')
import datetime
init_date = '2013-01-01'
#init_date = '2020-01-01'
init_date_object = datetime.datetime.strptime(init_date, '%Y-%m-%d').date()

date_now = datetime.date.today()

diff_years = date_now.year - init_date_object.year
year_window = 1


cryptos_list = [ 'BTC','ETH','SOL','XRP','ADA','DOT'] 
#cryptos_list = ['BTC','ETH']

if year_window > diff_years:
    raise ValueError("O intervalo de anos (year_window) é maior do que o período disponível nos dados.")
end_time=date_now.strftime('%Y-%m-%d')
#

# %%
end_time=date_now.strftime('%Y-%m-%d')
SHD.get_crypto_historical_data(['BTC'], '4h', '2025-01-01', end_time)
# Out:
#                    Date      Open      High       Low     Close       Volume  \
# 0   2025-01-01 00:00:00  93576.00  94509.42  93489.03  93838.04   1840.29813
# 1   2025-01-01 04:00:00  93838.04  93937.19  93500.00  93684.10    958.86153
# 2   2025-01-01 08:00:00  93684.11  93756.02  92888.00  93444.64   1867.48363
# 3   2025-01-01 12:00:00  93444.65  94500.00  93407.07  94432.94   2077.71092
# 4   2025-01-01 16:00:00  94432.94  94823.75  93760.93  94627.07   1721.05382
# ..                  ...       ...       ...       ...       ...          ...
# 670 2025-04-22 16:00:00  90934.61  91695.00  90624.03  91414.79   6380.71134
# 671 2025-04-22 20:00:00  91414.78  93888.00  91060.00  93442.99  10810.17098
# 672 2025-04-23 00:00:00  93442.99  93909.05  92580.18  93168.91   5215.33691
# 673 2025-04-23 04:00:00  93168.91  94264.00  93017.46  94133.82   3753.14233
# 674 2025-04-23 08:00:00  94133.82  94521.79  93340.81  93539.91   3978.17766
#
#         close_time   quote_asset_volume  number_of_trades taker_buy_base  \
# 0    1735703999999   172887549.10827950            263547   983.77686000
# 1    1735718399999    89845071.70986180            125393   492.49873000
# 2    1735732799999   174336252.70278310            252398   872.46741000
# 3    1735747199999   195302233.85939330            325179  1187.49923000
# 4    1735761599999   162204441.49634190            287980   869.51636000
# ..             ...                  ...               ...            ...
# 670  1745351999999   581443364.03632550            501068  2850.86218000
# 671  1745366399999  1000766353.76882060            789606  6729.38073000
# 672  1745380799999   485664111.27706930            427183  2418.99639000
# 673  1745395199999   351203753.09229570            295339  1940.28451000
# 674  1745409599999   373708370.01243340            326920  1888.19882000
#
#         taker_buy_quote ignore
# 0     92437151.72073710      0
# 1     46149202.59816590      0
# 2     81453194.67158030      0
# 3    111609153.41728430      0
# 4     81958370.53300280      0
# ..                  ...    ...
# 670  259892678.46963480      0
# 671  622751384.79869670      0
# 672  225389152.95870850      0
# 673  181634864.09645670      0
# 674  177432894.27525120      0
#
# [675 rows x 12 columns]

# %%
# define the used main path to save the data 
data_path ='./../../../Data_history'

# %%
#cryptos=cryptos_list[0]
for cryptos in cryptos_list:
    aux=[]
    for stride_year in range(0, diff_years-year_window+1,year_window):
        init_time=f'{init_date_object.year+stride_year}-01-01'

        look_year=init_date_object.year+stride_year+year_window
        if date_now.year == look_year:
            end_time=date_now.strftime('%Y-%m-%d')
        else:
            end_time=f'{look_year}-01-01'
        print(f'{cryptos} Dataset Period:{init_time} : {end_time}') 

        # Caminho do arquivo
        file_folder = f'{data_path}/{cryptos}_{interval}_{init_time}_{end_time}.csv'

        cryptos_df = SHD.get_crypto_historical_data([cryptos], interval, init_time, end_time)
        aux+=[cryptos_df]
    crypto_all_time_df = pd.concat(aux, ignore_index=True)

    init_data_df=crypto_all_time_df['Date'][0].strftime('%Y-%m-%d')
    file_folder = f'{data_path}/{cryptos}_{interval}_{init_data_df}_{end_time}.csv'
    crypto_all_time_df.to_csv(file_folder)
# Out:
# BTC Dataset Period:2013-01-01 : 2014-01-01
# Não há dados disponíveis.
# BTC Dataset Period:2014-01-01 : 2015-01-01
# Não há dados disponíveis.
# BTC Dataset Period:2015-01-01 : 2016-01-01
# Não há dados disponíveis.
# BTC Dataset Period:2016-01-01 : 2017-01-01
# Não há dados disponíveis.
# BTC Dataset Period:2017-01-01 : 2018-01-01
# BTC Dataset Period:2018-01-01 : 2019-01-01
# BTC Dataset Period:2019-01-01 : 2020-01-01
# BTC Dataset Period:2020-01-01 : 2021-01-01
# BTC Dataset Period:2021-01-01 : 2022-01-01
# BTC Dataset Period:2022-01-01 : 2023-01-01
# BTC Dataset Period:2023-01-01 : 2024-01-01
# BTC Dataset Period:2024-01-01 : 2025-04-23
# ETH Dataset Period:2013-01-01 : 2014-01-01
# Não há dados disponíveis.
# ETH Dataset Period:2014-01-01 : 2015-01-01
# Não há dados disponíveis.
# ETH Dataset Period:2015-01-01 : 2016-01-01
# Não há dados disponíveis.
# ETH Dataset Period:2016-01-01 : 2017-01-01
# Não há dados disponíveis.
# ETH Dataset Period:2017-01-01 : 2018-01-01
# ETH Dataset Period:2018-01-01 : 2019-01-01
# ETH Dataset Period:2019-01-01 : 2020-01-01
# ETH Dataset Period:2020-01-01 : 2021-01-01
# ETH Dataset Period:2021-01-01 : 2022-01-01
# ETH Dataset Period:2022-01-01 : 2023-01-01
# ETH Dataset Period:2023-01-01 : 2024-01-01
# ETH Dataset Period:2024-01-01 : 2025-04-23
# SOL Dataset Period:2013-01-01 : 2014-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2014-01-01 : 2015-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2015-01-01 : 2016-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2016-01-01 : 2017-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2017-01-01 : 2018-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2018-01-01 : 2019-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2019-01-01 : 2020-01-01
# Não há dados disponíveis.
# SOL Dataset Period:2020-01-01 : 2021-01-01
# SOL Dataset Period:2021-01-01 : 2022-01-01
# SOL Dataset Period:2022-01-01 : 2023-01-01
# SOL Dataset Period:2023-01-01 : 2024-01-01
# SOL Dataset Period:2024-01-01 : 2025-04-23
# XRP Dataset Period:2013-01-01 : 2014-01-01
# Não há dados disponíveis.
# XRP Dataset Period:2014-01-01 : 2015-01-01
# Não há dados disponíveis.
# XRP Dataset Period:2015-01-01 : 2016-01-01
# Não há dados disponíveis.
# XRP Dataset Period:2016-01-01 : 2017-01-01
# Não há dados disponíveis.
# XRP Dataset Period:2017-01-01 : 2018-01-01
# Não há dados disponíveis.
# XRP Dataset Period:2018-01-01 : 2019-01-01
# XRP Dataset Period:2019-01-01 : 2020-01-01
# XRP Dataset Period:2020-01-01 : 2021-01-01
# XRP Dataset Period:2021-01-01 : 2022-01-01
# XRP Dataset Period:2022-01-01 : 2023-01-01
# XRP Dataset Period:2023-01-01 : 2024-01-01
# XRP Dataset Period:2024-01-01 : 2025-04-23
# ADA Dataset Period:2013-01-01 : 2014-01-01
# Não há dados disponíveis.
# ADA Dataset Period:2014-01-01 : 2015-01-01
# Não há dados disponíveis.
# ADA Dataset Period:2015-01-01 : 2016-01-01
# Não há dados disponíveis.
# ADA Dataset Period:2016-01-01 : 2017-01-01
# Não há dados disponíveis.
# ADA Dataset Period:2017-01-01 : 2018-01-01
# Não há dados disponíveis.
# ADA Dataset Period:2018-01-01 : 2019-01-01
# ADA Dataset Period:2019-01-01 : 2020-01-01
# ADA Dataset Period:2020-01-01 : 2021-01-01
# ADA Dataset Period:2021-01-01 : 2022-01-01
# ADA Dataset Period:2022-01-01 : 2023-01-01
# ADA Dataset Period:2023-01-01 : 2024-01-01
# ADA Dataset Period:2024-01-01 : 2025-04-23
# DOT Dataset Period:2013-01-01 : 2014-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2014-01-01 : 2015-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2015-01-01 : 2016-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2016-01-01 : 2017-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2017-01-01 : 2018-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2018-01-01 : 2019-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2019-01-01 : 2020-01-01
# Não há dados disponíveis.
# DOT Dataset Period:2020-01-01 : 2021-01-01
# DOT Dataset Period:2021-01-01 : 2022-01-01
# DOT Dataset Period:2022-01-01 : 2023-01-01
# DOT Dataset Period:2023-01-01 : 2024-01-01
# DOT Dataset Period:2024-01-01 : 2025-04-23

# %%
from glob import glob
[crypto_data for crypto_data in glob("{data_path}/*")  if cryptos in crypto_data][0]
cryptos_df=pd.read_csv(file_folder, index_col=0)
