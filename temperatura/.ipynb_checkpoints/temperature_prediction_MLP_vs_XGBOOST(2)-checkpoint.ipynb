# %% [markdown]
# ## Predict Daily Minimum Temperatures pipeline

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import glob

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Reshape
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping
import xgboost as xgb

import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, LSTM, Dense, Concatenate, Activation, BatchNormalization, MaxPooling1D, Dropout, add, Bidirectional, Flatten, RepeatVector
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.initializers import RandomUniform, glorot_uniform, he_uniform

#AveragePooling1D, BatchNormalization, Flatten, Dropout, SpatialDropout1D, GRU, GlobalAveragePooling1D
from tensorflow.keras import Input
# Out:
# 2023-06-26 20:24:44.641367: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-26 20:24:44.729771: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-26 20:24:44.732140: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-06-26 20:24:44.732151: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-06-26 20:24:45.183879: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-06-26 20:24:45.183914: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-06-26 20:24:45.183918: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 2023-06-26 20:24:45.585912: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-06-26 20:24:45.585933: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-06-26 20:24:45.585949: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (N3N0B600577910H): /proc/driver/nvidia/version does not exist

# %% [markdown]
# ### Load and preprocessing the dataset

# %%
filenames = sorted(glob.glob('Data/*'))
filenames[:5]
# Out:
# ['Data/2000_2000_Jan_Mai.csv',
#  'Data/2000_2000_Jun_Nov.csv',
#  'Data/2000_2001_Dez_Mai.csv',
#  'Data/2001_2001_Jun_Nov.csv',
#  'Data/2001_2002_Dez_Mai.csv']

# %%
data_df = pd.DataFrame()
names=['Data','Hora (UTC)','Temp. Ins. (C)','Temp. Max. (C)','Temp. Min. (C)','Umi. Ins. (%)','Umi. Max. (%)','Umi. Min. (%)','Chuva (mm)']

for filename in filenames:
    try:
        df_aux = pd.read_csv(filename, usecols=names)
    except:
        df_aux = pd.read_csv(filename, usecols=names, sep=';')
        
    if(len(df_aux) == 0):
        data_df = df_aux
    else:
        data_df = pd.concat([data_df, df_aux])
    
    del df_aux
        
print(data_df.shape)
data_df.tail()
# Out:
# (205656, 9)
#             Data  Hora (UTC) Temp. Ins. (C) Temp. Max. (C) Temp. Min. (C)  \
# 3307  18/05/2023        1900           32,2           32,4           30,5
# 3308  18/05/2023        2000           30,8           32,5           30,7
# 3309  18/05/2023        2100           29,2           30,9           29,2
# 3310  18/05/2023        2200           28,9           29,4           28,8
# 3311  18/05/2023        2300           28,2           29,0           28,2
#
#      Umi. Ins. (%) Umi. Max. (%) Umi. Min. (%) Chuva (mm)
# 3307          57,0          67,0          57,0        0,0
# 3308          63,0          63,0          55,0        0,0
# 3309          74,0          74,0          63,0        0,0
# 3310          73,0          75,0          70,0        0,0
# 3311          82,0          82,0          73,0        0,0

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205656 entries, 0 to 3311
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Data            205656 non-null  object
#  1   Hora (UTC)      205656 non-null  int64
#  2   Temp. Ins. (C)  168174 non-null  object
#  3   Temp. Max. (C)  167524 non-null  object
#  4   Temp. Min. (C)  167523 non-null  object
#  5   Umi. Ins. (%)   167907 non-null  object
#  6   Umi. Max. (%)   167250 non-null  object
#  7   Umi. Min. (%)   167247 non-null  object
#  8   Chuva (mm)      168085 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 15.7+ MB

# %% [markdown]
# ### Preprocessing

# %%
for col in data_df.columns[2:]:
    data_df[col] = data_df[col].astype(str).str.replace(',','.').astype(float)
data_df['Data']=pd.to_datetime(data_df['Data'])
data_df
# Out:
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '17/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '19/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '20/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '21/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '22/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '24/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '26/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '27/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '28/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '29/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '30/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '31/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '17/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '19/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '20/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '21/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '22/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '24/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '26/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '27/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '28/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '29/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '17/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '19/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '20/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '21/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '22/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '24/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '26/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '27/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '28/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '29/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '30/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '31/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '17/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '19/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '20/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '21/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '22/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '24/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '26/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '27/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '28/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '29/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '30/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '17/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '19/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '20/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '21/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '22/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '24/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '26/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '27/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '28/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '29/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '30/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '31/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '17/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '19/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '20/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '21/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '22/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '24/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '26/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '27/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '28/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '29/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '30/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '17/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '19/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '20/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '21/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '22/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '24/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '26/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '27/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '28/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '29/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '30/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '31/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '17/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '19/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '20/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '21/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '22/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '24/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '26/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '27/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '28/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '29/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '30/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '31/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '17/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '19/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '20/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '21/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '22/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '24/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '26/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '27/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '28/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '29/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '24/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '26/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '27/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '28/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '17/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '19/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '20/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '21/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '22/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '24/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '26/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '27/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '28/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '29/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '30/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '31/03/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '17/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '19/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '20/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '21/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '22/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '24/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '26/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '27/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '28/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '29/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '30/04/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '16/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '17/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/05/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#            Data  Hora (UTC)  Temp. Ins. (C)  Temp. Max. (C)  Temp. Min. (C)  \
# 0    2000-01-01           0             NaN             NaN             NaN
# 1    2000-01-01         100             NaN             NaN             NaN
# 2    2000-01-01         200             NaN             NaN             NaN
# 3    2000-01-01         300             NaN             NaN             NaN
# 4    2000-01-01         400             NaN             NaN             NaN
# ...         ...         ...             ...             ...             ...
# 3307 2023-05-18        1900            32.2            32.4            30.5
# 3308 2023-05-18        2000            30.8            32.5            30.7
# 3309 2023-05-18        2100            29.2            30.9            29.2
# 3310 2023-05-18        2200            28.9            29.4            28.8
# 3311 2023-05-18        2300            28.2            29.0            28.2
#
#       Umi. Ins. (%)  Umi. Max. (%)  Umi. Min. (%)  Chuva (mm)
# 0               NaN            NaN            NaN         NaN
# 1               NaN            NaN            NaN         NaN
# 2               NaN            NaN            NaN         NaN
# 3               NaN            NaN            NaN         NaN
# 4               NaN            NaN            NaN         NaN
# ...             ...            ...            ...         ...
# 3307           57.0           67.0           57.0         0.0
# 3308           63.0           63.0           55.0         0.0
# 3309           74.0           74.0           63.0         0.0
# 3310           73.0           75.0           70.0         0.0
# 3311           82.0           82.0           73.0         0.0
#
# [205656 rows x 9 columns]

# %%
aux1=data_df.groupby(['Data'])['Temp. Ins. (C)','Umi. Ins. (%)','Chuva (mm)'].agg('mean')
aux2=data_df.groupby(['Data'])['Temp. Max. (C)','Umi. Max. (%)'].agg('max')
aux3=data_df.groupby(['Data'])['Temp. Min. (C)','Umi. Min. (%)'].agg('min')
data_df= pd.concat([aux1, aux2,aux3], axis=1).reset_index()
data_df
# Out:
# /tmp/ipykernel_76546/2876059681.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   aux1=data_df.groupby(['Data'])['Temp. Ins. (C)','Umi. Ins. (%)','Chuva (mm)'].agg('mean')
# /tmp/ipykernel_76546/2876059681.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   aux2=data_df.groupby(['Data'])['Temp. Max. (C)','Umi. Max. (%)'].agg('max')
# /tmp/ipykernel_76546/2876059681.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   aux3=data_df.groupby(['Data'])['Temp. Min. (C)','Umi. Min. (%)'].agg('min')
#            Data  Temp. Ins. (C)  Umi. Ins. (%)  Chuva (mm)  Temp. Max. (C)  \
# 0    2000-01-01             NaN            NaN         NaN             NaN
# 1    2000-01-02             NaN            NaN         NaN             NaN
# 2    2000-01-03             NaN            NaN         NaN             NaN
# 3    2000-01-04             NaN            NaN         NaN             NaN
# 4    2000-01-05             NaN            NaN         NaN             NaN
# ...         ...             ...            ...         ...             ...
# 8534 2023-12-01       27.686957      76.478261    0.113043            32.7
# 8535 2023-12-02       25.912500      87.541667    1.800000            30.8
# 8536 2023-12-03       24.570833      95.291667    2.908333            25.9
# 8537 2023-12-04       28.950000      74.208333    0.000000            33.8
# 8538 2023-12-05       26.233333      80.083333    0.016667            31.6
#
#       Umi. Max. (%)  Temp. Min. (C)  Umi. Min. (%)
# 0               NaN             NaN            NaN
# 1               NaN             NaN            NaN
# 2               NaN             NaN            NaN
# 3               NaN             NaN            NaN
# 4               NaN             NaN            NaN
# ...             ...             ...            ...
# 8534           92.0            24.2           56.0
# 8535           98.0            22.8           64.0
# 8536           97.0            22.9           91.0
# 8537           94.0            25.5           50.0
# 8538           95.0            23.2           60.0
#
# [8539 rows x 8 columns]

# %%
data_df.isna().sum()
# Out:
# Data                 0
# Temp. Ins. (C)    1183
# Umi. Ins. (%)     1185
# Chuva (mm)        1186
# Temp. Max. (C)    1198
# Umi. Max. (%)     1201
# Temp. Min. (C)    1198
# Umi. Min. (%)     1201
# dtype: int64

# %%
fig, axes = plt.subplots(3, 1, figsize=(10,10))

data_df.plot.scatter(x='Data',y='Temp. Min. (C)', ax= axes[0])
data_df.plot(x='Data',y='Temp. Max. (C)', ax= axes[1])
data_df.plot(x='Data',y='Temp. Ins. (C)', ax= axes[2])
# Out:
# /home/bruno.dutra/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='Data'>

# %%
new_data=data_df.ffill()[data_df['Data']>'2010-01-02']
new_data=new_data.ffill()
#new_data=new_data.bfill()
#new_data=new_data.interpolate()

# %%
fig, axes = plt.subplots(3, 1, figsize=(10,10))

new_data.plot(x='Data',y='Temp. Min. (C)', ax= axes[0])
new_data.plot(x='Data',y='Temp. Max. (C)', ax= axes[1])
new_data.plot(x='Data',y='Temp. Ins. (C)', ax= axes[2])
# Out:
# <AxesSubplot: xlabel='Data'>

# %%
new_data['week']=new_data['Data'].dt.week
new_data['weekday']=new_data['Data'].dt.weekday+1
new_data['day']=new_data['Data'].dt.day
new_data['month']=new_data['Data'].dt.month
new_data['quarter']=new_data['Data'].dt.quarter
# Out:
# /tmp/ipykernel_76546/2780441076.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   new_data['week']=new_data['Data'].dt.week

# %%
columns=new_data.columns[new_data.isna().sum().values <100]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 1, figsize=(30,10))

corrmat = new_data[columns].corr()
mask= np.zeros_like(corrmat)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corrmat,
            vmax=1, vmin=-1,
            annot=True, annot_kws={'fontsize':15},
            cmap=sns.diverging_palette(20,220,as_cmap=True))
plt.show()

# %%
#sns.pairplot(data[columns])

# %% [markdown]
# ### Init pipeline

# %%
data= pd.DataFrame()
data['Date']=new_data['Data']
data['Temp max']=new_data['Temp. Max. (C)']
data['Temp min']=new_data['Temp. Min. (C)']

# %%
Steps_ahead=180
windows_size=180

# %% [markdown]
# ### Processing the data

# %%
data = data.set_index('Date')

real_temp=data[-Steps_ahead:]
data=data[0:-Steps_ahead]

# %% [markdown]
# #### Splitting data into train and vall sets

# %%
idx_train_vall=(len(data)//3)
idx_train=range(0,len(data)-idx_train_vall)
idX_vall=range(len(data)-idx_train_vall,len(data))

# %%
#idx_train, idX_vall = train_vall_split(np.arange(len(data)), vall_size=0.2, shuffle=False)

#idx_train

#train= data['Temp'][idx_train].values.reshape(-1, 1)
#vall= data['Temp'][idX_vall].values.reshape(-1, 1)

train=data.reset_index().iloc[idx_train,:]
train_norm= train.copy()
vall=data.reset_index().iloc[idX_vall,:]
vall_norm= vall.copy()
# scale the data - normalization
scaler = MinMaxScaler()
train_norm[['Temp max','Temp min']] = scaler.fit_transform(train[['Temp max','Temp min']].values.reshape(-1, 2))
vall_norm[['Temp max','Temp min']] = scaler.transform(vall[['Temp max','Temp min']].values.reshape(-1, 2))

#pd.DataFrame(data).describe()

# %%
# Creating the input and output data for the neural network
def create_dataset(windows_size, data, Date=None):
    X, Y = [], []
    t_date =[]
    for i in range(len(data)-windows_size):
        X.append(data[i:i+windows_size])
        Y.append(data[i+windows_size])
        if [Date] != None:
            t_date+=[Date[i+windows_size]]
    if [Date] != None:
        return np.expand_dims(np.vstack(X),2).reshape(-1,windows_size,2), np.array(Y), np.array(t_date)
    else: 
        return np.expand_dims(np.vstack(X),2).reshape(-1,windows_size,2), np.array(Y)

X_train, Y_train, t_train = create_dataset(windows_size ,train_norm[['Temp max','Temp min']].values,train_norm['Date'].values)
X_vall, y_vall, t_vall = create_dataset(windows_size, vall_norm[['Temp max','Temp min']].values,vall_norm['Date'].values)

# %%
X_train.shape
# Out:
# (2956, 180, 2)

# %% [markdown]
# #### Plot the real temperature values

# %%
y_real_train= scaler.inverse_transform(Y_train.reshape(-1,2))
y_real_train_T = pd.to_datetime(t_train)

y_real_vall= scaler.inverse_transform(y_vall.reshape(-1,2))

y_real_vall_T = pd.to_datetime(t_vall)

fig=plt.figure(figsize=(12, 12))

ax1=plt.subplot(2,1,1)
plt.plot(y_real_train_T,y_real_train, color='red', label=['Max','Min'])
ax1.set_title('Daily Minimum Temperatures - Train dat')
ax1.set_xlabel('Time (in days)')
ax1.set_ylabel('Temperature (in Celsius degrees)')
ax1.legend()

ax2=plt.subplot(2,1,2)
plt.plot(y_real_vall_T,y_real_vall, color='blue', label=['Max','Min'])
ax2.set_title('Daily Minimum Temperatures - vall dat')
ax2.set_xlabel('Time (in days)')
ax2.set_ylabel('Temperature (in Celsius degrees)')
ax2.legend()

plt.show()

# %% [markdown]
# ### deep learning model

# %%
# Set the random seed
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from tensorflow.keras.initializers import RandomUniform, glorot_uniform, he_uniform
from tensorflow.keras.layers import GRU, Dense

model_name= "CNN_LSTM"
np.random.seed(42)
def CNN_LSTM(data_input):
    # define model architecture
    model = Sequential()
   
    model.add(Conv1D(64, kernel_size=3, strides=1, activation='relu',input_shape=(windows_size,2), kernel_initializer=he_uniform(seed=42), bias_initializer='zeros'))
    model.add(MaxPooling1D(2))
    model.add(GRU(64, kernel_initializer=he_uniform(seed=42), bias_initializer='zeros'))
    
    model.add(Dropout(0.2))
    model.add(Flatten())
    return model

def dense_layers(features, n_outputs=1, name=None):
    model=features

    # layer 2
    model.add( tf.keras.layers.Dense(32, kernel_initializer=he_uniform(seed=42), bias_initializer='zeros'))
    model.add(tf.keras.layers.Activation(tf.keras.activations.relu))

    # layer 3 - Output Layer 
    model.add(tf.keras.layers.Dense(n_outputs))
    model.add(tf.keras.layers.Activation(tf.keras.activations.linear))
    return model

features = CNN_LSTM(X_train)
model=dense_layers(features, n_outputs = 2)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 178, 64)           448
#
#  max_pooling1d (MaxPooling1D  (None, 89, 64)           0
#  )
#
#  gru (GRU)                   (None, 64)                24960
#
#  dropout (Dropout)           (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 32)                2080
#
#  activation (Activation)     (None, 32)                0
#
#  dense_1 (Dense)             (None, 2)                 66
#
#  activation_1 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 27,554
# Trainable params: 27,554
# Non-trainable params: 0
# _________________________________________________________________
# 2023-06-26 20:25:01.892560: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#plotting the model architechture
from tensorflow.keras.utils import plot_model
# Plot the model architecture
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# #### Callbacks

# %%
EarlyStopping=tf.keras.callbacks.EarlyStopping( monitor="val_loss", patience=30, verbose=1, mode="min", restore_best_weights=True,)

checkpoint_filepath =f'models/{model_name}_{windows_size}_temp'

csvLogger = tf.keras.callbacks.CSVLogger(checkpoint_filepath+'_history.csv', separator=',',append=True)

print("Training model :", checkpoint_filepath)

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, verbose=1, save_weights_only=False, monitor='val_loss', mode='min', save_best_only=True)

reduceLr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor = 0.2, patience = 3, min_lr=1e-14,verbose=1)
#lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20))
# Out:
# Training model : models/CNN_LSTM_180_temp

# %% [markdown]
# #### metrics

# %%
from tensorflow.keras import backend as K

def R2(y_true, y_pred): # squareds Pearson's correlation coef 
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot - K.epsilon()) )

def NRMSE(y_true, y_pred): # normalized_root_mean_squared_error
    return 1-K.sqrt(K.mean(K.square(y_pred - y_true))) 

MSE= tf.keras.losses.mean_squared_error
MAE = tf.keras.losses.mean_absolute_error
MAPE = tf.keras.losses.mean_absolute_percentage_error

# %%
optimizer1 = tf.keras.optimizers.Adam(learning_rate=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-08, amsgrad=True, name="Adam")
#optimizer1 = tf.keras.optimizers.SGD(lr=0.01, momentum=0.9)
#optimizer1 = tf.keras.optimizers.RMSprop()

model.compile(loss=tf.keras.losses.mse, optimizer=optimizer1,metrics=[NRMSE])
history=model.fit( x=X_train, y=Y_train, shuffle=True, validation_data=(X_vall,y_vall), epochs=200, batch_size=255,callbacks=[EarlyStopping,model_checkpoint_callback,reduceLr])
# Out:
# Epoch 1/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.3479 - NRMSE: 0.5392
# Epoch 1: val_loss improved from inf to 0.01277, saving model to models/CNN_LSTM_180_temp
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _update_step_xla, gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# 12/12 [==============================] - 4s 273ms/step - loss: 0.3320 - NRMSE: 0.5619 - val_loss: 0.0128 - val_NRMSE: 0.8863 - lr: 0.0100
# Epoch 2/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0332 - NRMSE: 0.8179
# Epoch 2: val_loss improved from 0.01277 to 0.01273, saving model to models/CNN_LSTM_180_temp
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _update_step_xla, gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# 12/12 [==============================] - 3s 255ms/step - loss: 0.0331 - NRMSE: 0.8184 - val_loss: 0.0127 - val_NRMSE: 0.8873 - lr: 0.0100
# Epoch 3/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0239 - NRMSE: 0.8458
# Epoch 3: val_loss improved from 0.01273 to 0.01219, saving model to models/CNN_LSTM_180_temp
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _update_step_xla, gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# 12/12 [==============================] - 3s 238ms/step - loss: 0.0235 - NRMSE: 0.8478 - val_loss: 0.0122 - val_NRMSE: 0.8888 - lr: 0.0100
# Epoch 4/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0184 - NRMSE: 0.8644
# Epoch 4: val_loss improved from 0.01219 to 0.01211, saving model to models/CNN_LSTM_180_temp
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _update_step_xla, gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# 12/12 [==============================] - 3s 262ms/step - loss: 0.0186 - NRMSE: 0.8633 - val_loss: 0.0121 - val_NRMSE: 0.8896 - lr: 0.0100
# Epoch 5/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0161 - NRMSE: 0.8733
# Epoch 5: val_loss did not improve from 0.01211
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0161 - NRMSE: 0.8734 - val_loss: 0.0124 - val_NRMSE: 0.8880 - lr: 0.0100
# Epoch 6/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0151 - NRMSE: 0.8773
# Epoch 6: val_loss improved from 0.01211 to 0.01188, saving model to models/CNN_LSTM_180_temp
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _update_step_xla, gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# 12/12 [==============================] - 3s 231ms/step - loss: 0.0151 - NRMSE: 0.8774 - val_loss: 0.0119 - val_NRMSE: 0.8907 - lr: 0.0100
# Epoch 7/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0150 - NRMSE: 0.8776
# Epoch 7: val_loss improved from 0.01188 to 0.01183, saving model to models/CNN_LSTM_180_temp
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _update_step_xla, gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# 12/12 [==============================] - 3s 274ms/step - loss: 0.0150 - NRMSE: 0.8776 - val_loss: 0.0118 - val_NRMSE: 0.8908 - lr: 0.0100
# Epoch 8/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0145 - NRMSE: 0.8798
# Epoch 8: val_loss did not improve from 0.01183
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0145 - NRMSE: 0.8795 - val_loss: 0.0118 - val_NRMSE: 0.8907 - lr: 0.0100
# Epoch 9/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0144 - NRMSE: 0.8802
# Epoch 9: val_loss did not improve from 0.01183
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0144 - NRMSE: 0.8799 - val_loss: 0.0119 - val_NRMSE: 0.8904 - lr: 0.0100
# Epoch 10/200
# 12/12 [==============================] - ETA: 0s - loss: 0.0142 - NRMSE: 0.8809
# Epoch 10: val_loss did not improve from 0.01183
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0142 - NRMSE: 0.8809 - val_loss: 0.0120 - val_NRMSE: 0.8900 - lr: 0.0020
# Epoch 11/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0143 - NRMSE: 0.8803
# Epoch 11: val_loss improved from 0.01183 to 0.01178, saving model to models/CNN_LSTM_180_temp
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _update_step_xla, gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# 12/12 [==============================] - 3s 249ms/step - loss: 0.0143 - NRMSE: 0.8810 - val_loss: 0.0118 - val_NRMSE: 0.8912 - lr: 0.0020
# Epoch 12/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0138 - NRMSE: 0.8825
# Epoch 12: val_loss did not improve from 0.01178
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0139 - NRMSE: 0.8820 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 0.0020
# Epoch 13/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0142 - NRMSE: 0.8810
# Epoch 13: val_loss improved from 0.01178 to 0.01176, saving model to models/CNN_LSTM_180_temp
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _update_step_xla, gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# 12/12 [==============================] - 3s 268ms/step - loss: 0.0141 - NRMSE: 0.8819 - val_loss: 0.0118 - val_NRMSE: 0.8913 - lr: 0.0020
# Epoch 14/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0139 - NRMSE: 0.8819
# Epoch 14: val_loss improved from 0.01176 to 0.01175, saving model to models/CNN_LSTM_180_temp
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _update_step_xla, gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# INFO:tensorflow:Assets written to: models/CNN_LSTM_180_temp/assets
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# 12/12 [==============================] - 3s 252ms/step - loss: 0.0139 - NRMSE: 0.8823 - val_loss: 0.0117 - val_NRMSE: 0.8913 - lr: 0.0020
# Epoch 15/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0139 - NRMSE: 0.8822
# Epoch 15: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0139 - NRMSE: 0.8823 - val_loss: 0.0118 - val_NRMSE: 0.8908 - lr: 4.0000e-04
# Epoch 16/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0143 - NRMSE: 0.8807
# Epoch 16: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 81ms/step - loss: 0.0141 - NRMSE: 0.8815 - val_loss: 0.0118 - val_NRMSE: 0.8911 - lr: 4.0000e-04
# Epoch 17/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0141 - NRMSE: 0.8817
# Epoch 17: val_loss did not improve from 0.01175
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0140 - NRMSE: 0.8822 - val_loss: 0.0118 - val_NRMSE: 0.8908 - lr: 4.0000e-04
# Epoch 18/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0140 - NRMSE: 0.8817
# Epoch 18: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0140 - NRMSE: 0.8815 - val_loss: 0.0118 - val_NRMSE: 0.8908 - lr: 8.0000e-05
# Epoch 19/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0142 - NRMSE: 0.8812
# Epoch 19: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0141 - NRMSE: 0.8814 - val_loss: 0.0118 - val_NRMSE: 0.8909 - lr: 8.0000e-05
# Epoch 20/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0142 - NRMSE: 0.8809
# Epoch 20: val_loss did not improve from 0.01175
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0142 - NRMSE: 0.8810 - val_loss: 0.0118 - val_NRMSE: 0.8909 - lr: 8.0000e-05
# Epoch 21/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0142 - NRMSE: 0.8810
# Epoch 21: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0141 - NRMSE: 0.8815 - val_loss: 0.0118 - val_NRMSE: 0.8909 - lr: 1.6000e-05
# Epoch 22/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0139 - NRMSE: 0.8820
# Epoch 22: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0140 - NRMSE: 0.8815 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 1.6000e-05
# Epoch 23/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0141 - NRMSE: 0.8813
# Epoch 23: val_loss did not improve from 0.01175
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0141 - NRMSE: 0.8813 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 1.6000e-05
# Epoch 24/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0141 - NRMSE: 0.8812
# Epoch 24: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0141 - NRMSE: 0.8814 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 3.2000e-06
# Epoch 25/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0137 - NRMSE: 0.8831
# Epoch 25: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0139 - NRMSE: 0.8819 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 3.2000e-06
# Epoch 26/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0139 - NRMSE: 0.8820
# Epoch 26: val_loss did not improve from 0.01175
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0139 - NRMSE: 0.8821 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 3.2000e-06
# Epoch 27/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0142 - NRMSE: 0.8808
# Epoch 27: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0142 - NRMSE: 0.8813 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 6.4000e-07
# Epoch 28/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0140 - NRMSE: 0.8817
# Epoch 28: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 78ms/step - loss: 0.0140 - NRMSE: 0.8822 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 6.4000e-07
# Epoch 29/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0141 - NRMSE: 0.8811
# Epoch 29: val_loss did not improve from 0.01175
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.2799998785339995e-07.
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0141 - NRMSE: 0.8814 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 6.4000e-07
# Epoch 30/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0140 - NRMSE: 0.8820
# Epoch 30: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 78ms/step - loss: 0.0140 - NRMSE: 0.8813 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 1.2800e-07
# Epoch 31/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0141 - NRMSE: 0.8814
# Epoch 31: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0141 - NRMSE: 0.8813 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 1.2800e-07
# Epoch 32/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0140 - NRMSE: 0.8818
# Epoch 32: val_loss did not improve from 0.01175
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 2.5599996433811613e-08.
# 12/12 [==============================] - 1s 78ms/step - loss: 0.0140 - NRMSE: 0.8819 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 1.2800e-07
# Epoch 33/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0143 - NRMSE: 0.8806
# Epoch 33: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0142 - NRMSE: 0.8810 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 2.5600e-08
# Epoch 34/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0136 - NRMSE: 0.8835
# Epoch 34: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 78ms/step - loss: 0.0137 - NRMSE: 0.8826 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 2.5600e-08
# Epoch 35/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0142 - NRMSE: 0.8810
# Epoch 35: val_loss did not improve from 0.01175
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 5.1199993578165965e-09.
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0142 - NRMSE: 0.8810 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 2.5600e-08
# Epoch 36/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0140 - NRMSE: 0.8817
# Epoch 36: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0140 - NRMSE: 0.8816 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 5.1200e-09
# Epoch 37/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0140 - NRMSE: 0.8820
# Epoch 37: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0139 - NRMSE: 0.8820 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 5.1200e-09
# Epoch 38/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0141 - NRMSE: 0.8815
# Epoch 38: val_loss did not improve from 0.01175
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.023999907090456e-09.
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0141 - NRMSE: 0.8810 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 5.1200e-09
# Epoch 39/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0142 - NRMSE: 0.8812
# Epoch 39: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 77ms/step - loss: 0.0141 - NRMSE: 0.8815 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 1.0240e-09
# Epoch 40/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0141 - NRMSE: 0.8813
# Epoch 40: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0141 - NRMSE: 0.8816 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 1.0240e-09
# Epoch 41/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0140 - NRMSE: 0.8816
# Epoch 41: val_loss did not improve from 0.01175
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 2.0479997697719911e-10.
# 12/12 [==============================] - 1s 76ms/step - loss: 0.0141 - NRMSE: 0.8811 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 1.0240e-09
# Epoch 42/200
# 12/12 [==============================] - ETA: 0s - loss: 0.0142 - NRMSE: 0.8806
# Epoch 42: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 84ms/step - loss: 0.0142 - NRMSE: 0.8806 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 2.0480e-10
# Epoch 43/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0139 - NRMSE: 0.8820
# Epoch 43: val_loss did not improve from 0.01175
# 12/12 [==============================] - 1s 79ms/step - loss: 0.0140 - NRMSE: 0.8816 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 2.0480e-10
# Epoch 44/200
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0140 - NRMSE: 0.8819Restoring model weights from the end of the best epoch: 14.
#
# Epoch 44: val_loss did not improve from 0.01175
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 4.095999650566285e-11.
# 12/12 [==============================] - 1s 78ms/step - loss: 0.0140 - NRMSE: 0.8816 - val_loss: 0.0118 - val_NRMSE: 0.8910 - lr: 2.0480e-10
# Epoch 44: early stopping

# %%
plt.figure(1,figsize=(20,10))  
# summarize history for accuracy  
plt.subplot(211)  
plt.plot(history.history['NRMSE']) 
plt.plot(history.history['val_NRMSE'])  
plt.title('model NRMSE')  
plt.ylabel('NRMSE')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation'], loc='upper left') 
# summarize history for loss  
plt.subplot(212)  
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])   
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation'], loc='upper left')  
plt.show()

# %%
checkpoint_filepath
# Out:
# 'models/CNN_LSTM_180_temp'

# %%
from tensorflow import keras
model=keras.models.load_model(checkpoint_filepath, custom_objects={'NRMSE':NRMSE})

# %%
def R2(y_true, y_pred): # squareds Pearson's correlation coef 
    SS_res =  np.sum(np.square( y_true-y_pred ))
    SS_tot = np.sum(np.square( y_true - np.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot) )


y_pred=scaler.inverse_transform(model.predict(X_vall))
r2_score= R2(y_real_vall, y_pred )
print('NN R2:', r2_score)
# Out:
# 44/44 [==============================] - 1s 7ms/step
# NN R2: 0.8675193797721907

# %%
# Evaluate the stacked model
mse = mean_squared_error(y_real_vall,y_pred)
print('NN MSE:', mse)
# Out:
# NN MSE: 2.4294451882271786

# %%
# Plot the real and predicted temperature values
plt.figure(figsize=(12, 6))
plt.plot(y_real_vall_T, y_real_vall, color='red', label=['Real Max','Real Min'])
plt.plot(y_real_vall_T,y_pred, color='blue', label='Predicted ')
plt.title(f'Daily Minimum Temperatures {model_name}')
plt.xlabel('Time (in days)')
plt.ylabel('Temperature (in Celsius degrees)')
plt.legend()
plt.show()

# %% [markdown]
# ### DNN

# %%
model_name= "MLP"
# Camada de entrada
input_data = Input(shape=(windows_size,2))

dense_output = Flatten()(input_data)

dense_output = Dense(128, activation='relu')(dense_output)
#dense_output=Dropout(0.5)(dense_output)

dense_output = Dense(128, activation='relu')(dense_output)
#dense_output=Dropout(0.5)(dense_output)

#dense_output = Dense(10, activation='relu')(dense_output)
#dense_output=Dropout(0.5)(dense_output)

# Camada de saída
output = Dense(2, activation='linear')(dense_output)


model_DNN = Model(inputs=input_data, outputs=output)
model_DNN.summary()


#plotting the model architechture
from tensorflow.keras.utils import plot_model
# Plot the model architecture
plot_model(model_DNN, show_shapes=True, show_layer_names=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 180, 2)]          0
#
#  flatten_1 (Flatten)         (None, 360)               0
#
#  dense_2 (Dense)             (None, 128)               46208
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 62,978
# Trainable params: 62,978
# Non-trainable params: 0
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
EarlyStopping=tf.keras.callbacks.EarlyStopping( monitor="val_loss", patience=30, verbose=1, mode="min", restore_best_weights=True,)
checkpoint_filepath =f'models/{model_name}_{windows_size}_temp'

csvLogger = tf.keras.callbacks.CSVLogger(checkpoint_filepath+'_history.csv', separator=',',append=True)

print("Training model :", checkpoint_filepath)

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, verbose=1, save_weights_only=False, monitor='val_loss', mode='min', save_best_only=True)

reduceLr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor = 0.2, patience = 3, min_lr=1e-14,verbose=1)
#lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20))
# Out:
# Training model : models/MLP_180_temp

# %%
from tensorflow.keras import backend as K

MSE= tf.keras.losses.mean_squared_error
MAE = tf.keras.losses.mean_absolute_error
MAPE = tf.keras.losses.mean_absolute_percentage_error

optimizer1 = tf.keras.optimizers.Adam(learning_rate=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-08, amsgrad=True, name="Adam")
#optimizer1 = tf.keras.optimizers.SGD(lr=0.01, momentum=0.9)
#optimizer1 = tf.keras.optimizers.RMSprop()

# %%
model_DNN.compile(loss=tf.keras.losses.mse, optimizer=optimizer1,metrics=[NRMSE])
history=model_DNN.fit( x=X_train, y=Y_train, shuffle=True, validation_data=(X_vall,y_vall), epochs=200, batch_size=255,callbacks=[EarlyStopping,model_checkpoint_callback,reduceLr])
# Out:
# Epoch 1/200
#  1/12 [=>............................] - ETA: 3s - loss: 0.2785 - NRMSE: 0.4723
# Epoch 1: val_loss improved from inf to 0.02533, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 1s 36ms/step - loss: 4.3410 - NRMSE: 0.0385 - val_loss: 0.0253 - val_NRMSE: 0.8378 - lr: 0.0100
# Epoch 2/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0314 - NRMSE: 0.8227
# Epoch 2: val_loss did not improve from 0.02533
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0325 - NRMSE: 0.8245 - val_loss: 0.0270 - val_NRMSE: 0.8374 - lr: 0.0100
# Epoch 3/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0335 - NRMSE: 0.8170
# Epoch 3: val_loss improved from 0.02533 to 0.01715, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0218 - NRMSE: 0.8544 - val_loss: 0.0171 - val_NRMSE: 0.8663 - lr: 0.0100
# Epoch 4/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0187 - NRMSE: 0.8631
# Epoch 4: val_loss improved from 0.01715 to 0.01396, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0171 - NRMSE: 0.8690 - val_loss: 0.0140 - val_NRMSE: 0.8815 - lr: 0.0100
# Epoch 5/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0173 - NRMSE: 0.8683
# Epoch 5: val_loss improved from 0.01396 to 0.01285, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 1s 52ms/step - loss: 0.0163 - NRMSE: 0.8725 - val_loss: 0.0129 - val_NRMSE: 0.8856 - lr: 0.0100
# Epoch 6/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0185 - NRMSE: 0.8641
# Epoch 6: val_loss did not improve from 0.01285
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0160 - NRMSE: 0.8738 - val_loss: 0.0142 - val_NRMSE: 0.8794 - lr: 0.0100
# Epoch 7/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0158 - NRMSE: 0.8741
# Epoch 7: val_loss improved from 0.01285 to 0.01237, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0154 - NRMSE: 0.8761 - val_loss: 0.0124 - val_NRMSE: 0.8880 - lr: 0.0100
# Epoch 8/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0177 - NRMSE: 0.8668
# Epoch 8: val_loss improved from 0.01237 to 0.01230, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0147 - NRMSE: 0.8786 - val_loss: 0.0123 - val_NRMSE: 0.8880 - lr: 0.0100
# Epoch 9/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0137 - NRMSE: 0.8830
# Epoch 9: val_loss did not improve from 0.01230
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0147 - NRMSE: 0.8787 - val_loss: 0.0130 - val_NRMSE: 0.8851 - lr: 0.0100
# Epoch 10/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0156 - NRMSE: 0.8750
# Epoch 10: val_loss improved from 0.01230 to 0.01189, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0143 - NRMSE: 0.8805 - val_loss: 0.0119 - val_NRMSE: 0.8903 - lr: 0.0100
# Epoch 11/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0147 - NRMSE: 0.8789
# Epoch 11: val_loss improved from 0.01189 to 0.01152, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0136 - NRMSE: 0.8835 - val_loss: 0.0115 - val_NRMSE: 0.8923 - lr: 0.0100
# Epoch 12/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0148 - NRMSE: 0.8785
# Epoch 12: val_loss did not improve from 0.01152
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0134 - NRMSE: 0.8841 - val_loss: 0.0148 - val_NRMSE: 0.8780 - lr: 0.0100
# Epoch 13/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0167 - NRMSE: 0.8708
# Epoch 13: val_loss did not improve from 0.01152
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0157 - NRMSE: 0.8751 - val_loss: 0.0128 - val_NRMSE: 0.8864 - lr: 0.0100
# Epoch 14/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0141 - NRMSE: 0.8814
# Epoch 14: val_loss did not improve from 0.01152
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0143 - NRMSE: 0.8809 - val_loss: 0.0121 - val_NRMSE: 0.8896 - lr: 0.0100
# Epoch 15/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0132 - NRMSE: 0.8852
# Epoch 15: val_loss improved from 0.01152 to 0.01129, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0130 - NRMSE: 0.8860 - val_loss: 0.0113 - val_NRMSE: 0.8934 - lr: 0.0020
# Epoch 16/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0135 - NRMSE: 0.8840
# Epoch 16: val_loss improved from 0.01129 to 0.01123, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0128 - NRMSE: 0.8870 - val_loss: 0.0112 - val_NRMSE: 0.8938 - lr: 0.0020
# Epoch 17/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0131 - NRMSE: 0.8855
# Epoch 17: val_loss did not improve from 0.01123
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0127 - NRMSE: 0.8875 - val_loss: 0.0113 - val_NRMSE: 0.8937 - lr: 0.0020
# Epoch 18/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0150 - NRMSE: 0.8776
# Epoch 18: val_loss improved from 0.01123 to 0.01122, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0127 - NRMSE: 0.8871 - val_loss: 0.0112 - val_NRMSE: 0.8939 - lr: 0.0020
# Epoch 19/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0135 - NRMSE: 0.8837
# Epoch 19: val_loss improved from 0.01122 to 0.01121, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0127 - NRMSE: 0.8875 - val_loss: 0.0112 - val_NRMSE: 0.8939 - lr: 4.0000e-04
# Epoch 20/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0124 - NRMSE: 0.8884
# Epoch 20: val_loss improved from 0.01121 to 0.01120, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0127 - NRMSE: 0.8877 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 4.0000e-04
# Epoch 21/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0134 - NRMSE: 0.8842
# Epoch 21: val_loss improved from 0.01120 to 0.01120, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# Epoch 21: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0127 - NRMSE: 0.8876 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 4.0000e-04
# Epoch 22/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0128 - NRMSE: 0.8869
# Epoch 22: val_loss did not improve from 0.01120
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0127 - NRMSE: 0.8875 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 8.0000e-05
# Epoch 23/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0128 - NRMSE: 0.8870
# Epoch 23: val_loss did not improve from 0.01120
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0126 - NRMSE: 0.8875 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 8.0000e-05
# Epoch 24/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0138 - NRMSE: 0.8824
# Epoch 24: val_loss improved from 0.01120 to 0.01120, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.599999814061448e-05.
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0126 - NRMSE: 0.8877 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 8.0000e-05
# Epoch 25/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0121 - NRMSE: 0.8902
# Epoch 25: val_loss improved from 0.01120 to 0.01119, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 1s 56ms/step - loss: 0.0126 - NRMSE: 0.8874 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 1.6000e-05
# Epoch 26/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0131 - NRMSE: 0.8855
# Epoch 26: val_loss improved from 0.01119 to 0.01119, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0126 - NRMSE: 0.8879 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 1.6000e-05
# Epoch 27/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0136 - NRMSE: 0.8833
# Epoch 27: val_loss improved from 0.01119 to 0.01119, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0126 - NRMSE: 0.8879 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 1.6000e-05
# Epoch 28/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0105 - NRMSE: 0.8975
# Epoch 28: val_loss improved from 0.01119 to 0.01119, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0126 - NRMSE: 0.8879 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 3.2000e-06
# Epoch 29/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0136 - NRMSE: 0.8832
# Epoch 29: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8877 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 3.2000e-06
# Epoch 30/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0126 - NRMSE: 0.8877
# Epoch 30: val_loss improved from 0.01119 to 0.01119, saving model to models/MLP_180_temp
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# INFO:tensorflow:Assets written to: models/MLP_180_temp/assets
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# 12/12 [==============================] - 0s 41ms/step - loss: 0.0126 - NRMSE: 0.8874 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 3.2000e-06
# Epoch 31/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0132 - NRMSE: 0.8850
# Epoch 31: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0126 - NRMSE: 0.8876 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 6.4000e-07
# Epoch 32/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0129 - NRMSE: 0.8863
# Epoch 32: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8877 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 6.4000e-07
# Epoch 33/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0128 - NRMSE: 0.8869
# Epoch 33: val_loss did not improve from 0.01119
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.2799998785339995e-07.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8877 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 6.4000e-07
# Epoch 34/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0120 - NRMSE: 0.8904
# Epoch 34: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8874 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 1.2800e-07
# Epoch 35/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0119 - NRMSE: 0.8911
# Epoch 35: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8877 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 1.2800e-07
# Epoch 36/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0124 - NRMSE: 0.8887
# Epoch 36: val_loss did not improve from 0.01119
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 2.5599996433811613e-08.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8876 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 1.2800e-07
# Epoch 37/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0103 - NRMSE: 0.8984
# Epoch 37: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8876 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 2.5600e-08
# Epoch 38/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0108 - NRMSE: 0.8959
# Epoch 38: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8875 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 2.5600e-08
# Epoch 39/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0131 - NRMSE: 0.8856
# Epoch 39: val_loss did not improve from 0.01119
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 5.1199993578165965e-09.
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0126 - NRMSE: 0.8878 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 2.5600e-08
# Epoch 40/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0118 - NRMSE: 0.8912
# Epoch 40: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8878 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 5.1200e-09
# Epoch 41/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0126 - NRMSE: 0.8878
# Epoch 41: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8875 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 5.1200e-09
# Epoch 42/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0122 - NRMSE: 0.8896
# Epoch 42: val_loss did not improve from 0.01119
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.023999907090456e-09.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8875 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 5.1200e-09
# Epoch 43/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0134 - NRMSE: 0.8843
# Epoch 43: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8875 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 1.0240e-09
# Epoch 44/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0130 - NRMSE: 0.8860
# Epoch 44: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8875 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 1.0240e-09
# Epoch 45/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0114 - NRMSE: 0.8933
# Epoch 45: val_loss did not improve from 0.01119
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.0479997697719911e-10.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8874 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 1.0240e-09
# Epoch 46/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0131 - NRMSE: 0.8854
# Epoch 46: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8875 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 2.0480e-10
# Epoch 47/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0123 - NRMSE: 0.8889
# Epoch 47: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8874 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 2.0480e-10
# Epoch 48/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0133 - NRMSE: 0.8849
# Epoch 48: val_loss did not improve from 0.01119
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 4.095999650566285e-11.
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0126 - NRMSE: 0.8873 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 2.0480e-10
# Epoch 49/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0122 - NRMSE: 0.8897
# Epoch 49: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0126 - NRMSE: 0.8871 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 4.0960e-11
# Epoch 50/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0130 - NRMSE: 0.8860
# Epoch 50: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8879 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 4.0960e-11
# Epoch 51/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0123 - NRMSE: 0.8890
# Epoch 51: val_loss did not improve from 0.01119
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 8.19199916235469e-12.
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0126 - NRMSE: 0.8880 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 4.0960e-11
# Epoch 52/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0112 - NRMSE: 0.8944
# Epoch 52: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8876 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 8.1920e-12
# Epoch 53/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0130 - NRMSE: 0.8861
# Epoch 53: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0126 - NRMSE: 0.8879 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 8.1920e-12
# Epoch 54/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0113 - NRMSE: 0.8936
# Epoch 54: val_loss did not improve from 0.01119
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.6383998324709382e-12.
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0126 - NRMSE: 0.8875 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 8.1920e-12
# Epoch 55/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0137 - NRMSE: 0.8829
# Epoch 55: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0126 - NRMSE: 0.8877 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 1.6384e-12
# Epoch 56/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0129 - NRMSE: 0.8864
# Epoch 56: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8875 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 1.6384e-12
# Epoch 57/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0131 - NRMSE: 0.8855
# Epoch 57: val_loss did not improve from 0.01119
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 3.2767996215737895e-13.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8875 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 1.6384e-12
# Epoch 58/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0131 - NRMSE: 0.8857
# Epoch 58: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8878 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 3.2768e-13
# Epoch 59/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0122 - NRMSE: 0.8894
# Epoch 59: val_loss did not improve from 0.01119
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0126 - NRMSE: 0.8880 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 3.2768e-13
# Epoch 60/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0131 - NRMSE: 0.8856Restoring model weights from the end of the best epoch: 30.
#
# Epoch 60: val_loss did not improve from 0.01119
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 6.553599351567796e-14.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - NRMSE: 0.8877 - val_loss: 0.0112 - val_NRMSE: 0.8940 - lr: 3.2768e-13
# Epoch 60: early stopping

# %%
plt.figure(1,figsize=(20,10))  
# summarize history for accuracy  
plt.subplot(211)  
plt.plot(history.history['NRMSE']) 
plt.plot(history.history['val_NRMSE'])  
plt.title('model NRMSE')  
plt.ylabel('NRMSE')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation'], loc='upper left') 
# summarize history for loss  
plt.subplot(212)  
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])   
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation'], loc='upper left')  
plt.show()

# %%
checkpoint_filepath
# Out:
# 'models/MLP_180_temp'

# %%
from tensorflow import keras
model_DNN=keras.models.load_model(checkpoint_filepath, custom_objects={'NRMSE':NRMSE})
# Evaluate the stacked model

y_pred_DNN=scaler.inverse_transform(model_DNN.predict(X_vall))
r2_score= R2(y_real_vall, y_pred_DNN )
print('NN R2:', r2_score)
mse = mean_squared_error(y_real_vall,y_pred)
print('NN MSE:', mse)
# Out:
# 44/44 [==============================] - 0s 830us/step
# NN R2: 0.875028812991199
# NN MSE: 2.4294451882271786

# %%
# Plot the real and predicted temperature values
plt.figure(figsize=(12, 6))
plt.plot(y_real_vall_T, y_real_vall, color='red', label=['Real Max','Real Min'])
plt.plot(y_real_vall_T,y_pred_DNN, color='blue', label='Predicted ')
plt.title(f'Daily Minimum Temperatures {model_name}')
plt.xlabel('Time (in days)')
plt.ylabel('Temperature (in Celsius degrees)')
plt.legend()
plt.show()

# %% [markdown]
# ### Generating the predicted values for the next Steps  periods

# %%
last_window_CNN = np.array(data.tail(windows_size)[['Temp max','Temp min']]).reshape(windows_size,2)
last_window_DNN=last_window_CNN.copy()

predicted_values_CNN = []
predicted_values_DNN = []

# %%
for i in range(Steps_ahead+1):
    ### NN 
    last_window_scaler_CNN= scaler.transform(last_window_CNN.reshape(-1,2))
    
    y_pred_CNN=model.predict(last_window_scaler_CNN.reshape(1,-1,2))
    
    predicted_values_CNN.append(scaler.inverse_transform(y_pred_CNN)[0])
    
    last_window_CNN = np.append(last_window_CNN[1:,:], predicted_values_CNN[-1].reshape(-1,2),axis=0)
    
    ################################
    last_window_scaler_DNN= scaler.transform(last_window_DNN.reshape(-1,2))
    
    y_pred_DNN=model_DNN.predict(last_window_scaler_DNN.reshape(1,-1,2))
    
    predicted_values_DNN.append(scaler.inverse_transform(y_pred_DNN)[0])
    
    last_window_DNN = np.append(last_window_DNN[1:,:], predicted_values_DNN[-1].reshape(-1,2),axis=0)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step

# %%
predicted_values_NN=np.vstack(predicted_values_NN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 predicted_values_NN=np.vstack(predicted_values_NN)
#
# NameError: name 'predicted_values_NN' is not defined

# %%
real_temp.index = pd.to_datetime(real_temp.index)
#predicted_values_NN= scaler.inverse_transform(np.array(predicted_values_NN).reshape(-1,1))
#predicted_values_xgb= scaler.inverse_transform(np.array(predicted_values_xgb).reshape(-1,1))


plt.figure(figsize=(12, 6))
plt.plot(real_temp.index, predicted_values_CNN, label=['Pred-CNN MAX','Pred-CNN MIN'])
plt.plot(real_temp.index, predicted_values_DNN, label=['Pred-DNN MAX','Pred-DNN MIN'])

plt.plot(real_temp.index, real_temp, label='Expected')
plt.legend()
plt.title('Temperature Forecast')
plt.xlabel('Time')
plt.ylabel('Temperature (Celsius)')
plt.show()

# %%
real_temp.index[-1]

# %%
predicted_values_DNN[-2:]
